# %%
# !pip3 install spotipy

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
#add your keys here
client_credentials_manager = SpotifyClientCredentials(client_id="enter your client id key", client_secret="enter your client secret key")

# %%
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/playlist/5GFsrP5Ba6lLvmX3Cf8e3R"

# %%
playlist_URI = playlist_link.split("/")[-1].split('?')[0] # spli("/") Corta/separa o link sempre que aparece um /, [-1] pega o ultima elemento, split('?') Corta/separa o link sempre que aparece um ?, [0] acessa o primrito elemento do playlist_link

# %%
playlist_link.split("/")
# Out:
# ['https:', '', 'open.spotify.com', 'playlist', '5GFsrP5Ba6lLvmX3Cf8e3R']

# %%
data = sp.playlist_tracks(playlist_URI)

# %%
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/5GFsrP5Ba6lLvmX3Cf8e3R/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2025-12-30T00:53:56Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1ejtmd43cd8jarti7a8cw1e8b'},
#     'href': 'https://api.spotify.com/v1/users/1ejtmd43cd8jarti7a8cw1e8b',
#     'id': '1ejtmd43cd8jarti7a8cw1e8b',
#     'type': 'user',
#     'uri': 'spotify:user:1ejtmd43cd8jarti7a8cw1e8b'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
# ...

# %%
data['items'][0]['track']['album']['id']
# Out:
# '3h14xzfMIytpzYxO4BhruL'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'I Love Kizomba 2'

# %%
data['items'][0]['track']['album']
# Out:
# {'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'BY',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
#   'NG',
# ...

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2019-08-09'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 22

# %%
data['items'][0]['track']['album']['external_urls']
# Out:
# {'spotify': 'https://open.spotify.com/album/3h14xzfMIytpzYxO4BhruL'}

# %%
# IT A DITIONARY
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_element = {'album_id':album_id, 'name':album_name, 'release_date':album_release_date,
                    'total_tracks':album_total_tracks, 'url':album_url}
    print(album_element)
# Out:
# {'album_id': '3h14xzfMIytpzYxO4BhruL', 'name': 'I Love Kizomba 2', 'release_date': '2019-08-09', 'total_tracks': 22, 'url': 'https://open.spotify.com/album/3h14xzfMIytpzYxO4BhruL'}
# {'album_id': '3kZ8kQRYbgqgD5HVEsAzv1', 'name': "Que c'est triste Venise", 'release_date': '1964-01-01', 'total_tracks': 12, 'url': 'https://open.spotify.com/album/3kZ8kQRYbgqgD5HVEsAzv1'}
# {'album_id': '7MwpCdsgZQTHDlDzqmVYuM', 'name': 'Holy Forever (Live)', 'release_date': '2024-06-28', 'total_tracks': 1, 'url': 'https://open.spotify.com/album/7MwpCdsgZQTHDlDzqmVYuM'}
# {'album_id': '1QBkVr9PrI46C43cZclE4Z', 'name': 'Emoções', 'release_date': '2023-06-30', 'total_tracks': 14, 'url': 'https://open.spotify.com/album/1QBkVr9PrI46C43cZclE4Z'}
# {'album_id': '52CD0NEh9KfaGGIQRv478y', 'name': 'Independência', 'release_date': '2021-04-30', 'total_tracks': 10, 'url': 'https://open.spotify.com/album/52CD0NEh9KfaGGIQRv478y'}

# %%
# LET'S CREATE A LIST OF ALBUM FOR DICTIONARI IN CODE ABOVE.
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_element = {'album_id':album_id, 'name':album_name, 'release_date':album_release_date,
                    'total_tracks':album_total_tracks, 'url':album_url}
    album_list.append(album_element)

# %%
album_list
# Out:
# [{'album_id': '3h14xzfMIytpzYxO4BhruL',
#   'name': 'I Love Kizomba 2',
#   'release_date': '2019-08-09',
#   'total_tracks': 22,
#   'url': 'https://open.spotify.com/album/3h14xzfMIytpzYxO4BhruL'},
#  {'album_id': '3kZ8kQRYbgqgD5HVEsAzv1',
#   'name': "Que c'est triste Venise",
#   'release_date': '1964-01-01',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/3kZ8kQRYbgqgD5HVEsAzv1'},
#  {'album_id': '7MwpCdsgZQTHDlDzqmVYuM',
#   'name': 'Holy Forever (Live)',
#   'release_date': '2024-06-28',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/7MwpCdsgZQTHDlDzqmVYuM'},
#  {'album_id': '1QBkVr9PrI46C43cZclE4Z',
#   'name': 'Emoções',
#   'release_date': '2023-06-30',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/1QBkVr9PrI46C43cZclE4Z'},
#  {'album_id': '52CD0NEh9KfaGGIQRv478y',
#   'name': 'Independência',
#   'release_date': '2021-04-30',
#   'total_tracks': 10,
# ...

# %%
data['items'][0]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1uFzeVANATmuj4SchQpYnt'},
#   'href': 'https://api.spotify.com/v1/artists/1uFzeVANATmuj4SchQpYnt',
#   'id': '1uFzeVANATmuj4SchQpYnt',
#   'name': 'Telma Lee',
#   'type': 'artist',
#   'uri': 'spotify:artist:1uFzeVANATmuj4SchQpYnt'}]

# %%
# ARTIST DICTIONARI 
for row in data['items']:
    for key, value in row.items():
        if key == 'track':
            print(value['artists'])
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1uFzeVANATmuj4SchQpYnt'}, 'href': 'https://api.spotify.com/v1/artists/1uFzeVANATmuj4SchQpYnt', 'id': '1uFzeVANATmuj4SchQpYnt', 'name': 'Telma Lee', 'type': 'artist', 'uri': 'spotify:artist:1uFzeVANATmuj4SchQpYnt'}]
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2hgP9Ap2tc10R5jrQaEpMT'}, 'href': 'https://api.spotify.com/v1/artists/2hgP9Ap2tc10R5jrQaEpMT', 'id': '2hgP9Ap2tc10R5jrQaEpMT', 'name': 'Charles Aznavour', 'type': 'artist', 'uri': 'spotify:artist:2hgP9Ap2tc10R5jrQaEpMT'}]
# ...

# %%
# TURN ARTIST DICTIONARI INTO ARTIST LIST.
artist_list = []
for row in data['items']:
    for key, value in row.items():
        if key == 'track':
            for artist in value['artists']:
                artist_dict = {'artist_id':artist['id'], 'artist_name':artist['name'], 
                               'external_url': artist['href']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '1uFzeVANATmuj4SchQpYnt',
#   'artist_name': 'Telma Lee',
#   'external_url': 'https://api.spotify.com/v1/artists/1uFzeVANATmuj4SchQpYnt'},
#  {'artist_id': '2hgP9Ap2tc10R5jrQaEpMT',
#   'artist_name': 'Charles Aznavour',
#   'external_url': 'https://api.spotify.com/v1/artists/2hgP9Ap2tc10R5jrQaEpMT'},
#  {'artist_id': '26T4yOaOoFJvUvxR87Y9HO',
#   'artist_name': 'Bethel Music',
#   'external_url': 'https://api.spotify.com/v1/artists/26T4yOaOoFJvUvxR87Y9HO'},
#  {'artist_id': '0cuW2lF0YWb9VUyHOnvnsO',
#   'artist_name': 'Jenn Johnson',
#   'external_url': 'https://api.spotify.com/v1/artists/0cuW2lF0YWb9VUyHOnvnsO'},
#  {'artist_id': '3qfrrrSO7utFdJkM2tvMRb',
#   'artist_name': 'CeCe Winans',
#   'external_url': 'https://api.spotify.com/v1/artists/3qfrrrSO7utFdJkM2tvMRb'},
#  {'artist_id': '1BHwRO5nJVVR0Vdn9vwDAs',
#   'artist_name': 'Edmázia Mayembe',
#   'external_url': 'https://api.spotify.com/v1/artists/1BHwRO5nJVVR0Vdn9vwDAs'},
# ...

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = { 'song_id':song_id, 'song_name':song_name, 'duration_ms':song_duration, 'url':song_url,
                     'popularity':song_popularity, 'song_added':song_added, 'album':album_id,
                     'artist_id':artist_id
                   }
    song_list.append(song_element)

# %%
album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df.head()
# Out:
#                  album_id                     name release_date  total_tracks  \
# 0  3h14xzfMIytpzYxO4BhruL         I Love Kizomba 2   2019-08-09            22
# 1  3kZ8kQRYbgqgD5HVEsAzv1  Que c'est triste Venise   1964-01-01            12
# 2  7MwpCdsgZQTHDlDzqmVYuM      Holy Forever (Live)   2024-06-28             1
# 3  1QBkVr9PrI46C43cZclE4Z                  Emoções   2023-06-30            14
# 4  52CD0NEh9KfaGGIQRv478y            Independência   2021-04-30            10
#
#                                                  url
# 0  https://open.spotify.com/album/3h14xzfMIytpzYx...
# 1  https://open.spotify.com/album/3kZ8kQRYbgqgD5H...
# 2  https://open.spotify.com/album/7MwpCdsgZQTHDlD...
# 3  https://open.spotify.com/album/1QBkVr9PrI46C43...
# 4  https://open.spotify.com/album/52CD0NEh9KfaGGI...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      5 non-null      object
#  1   name          5 non-null      object
#  2   release_date  5 non-null      object
#  3   total_tracks  5 non-null      int64
#  4   url           5 non-null      object
# dtypes: int64(1), object(4)
# memory usage: 332.0+ bytes

# %%
album_df = album_df.drop_duplicates(subset=['album_id'])

# %%
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
artist_df = artist_df.drop_duplicates(subset=['artist_id'])

# %%
#Song Dataframe
song_df = pd.DataFrame.from_dict(song_list)

# %%
song_df
# Out:
#                   song_id            song_name  duration_ms  \
# 0  6RLa40O5qY8xWKyyfw0zJ0              Sou Teu       203183
# 1  66TDFKCZpMRfLcgJpa15xq          Hier encore       143466
# 2  5txryUrKT15O1BCxIo88LR  Holy Forever (Live)       642837
# 3  5A6NI8jDFshJKTJmYQVgre               É Obra       230158
# 4  24qQClclS8CCjiCZKM8d9m     Njila ia Dikanga       341946
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/6RLa40O5qY8xWKy...          23
# 1  https://open.spotify.com/track/66TDFKCZpMRfLcg...          68
# 2  https://open.spotify.com/track/5txryUrKT15O1BC...          62
# 3  https://open.spotify.com/track/5A6NI8jDFshJKTJ...          41
# 4  https://open.spotify.com/track/24qQClclS8CCjiC...          44
#
#              song_added                   album               artist_id
# 0  2025-12-30T00:53:56Z  3h14xzfMIytpzYxO4BhruL  0LyfQWJT6nXafLPZqxe9Of
# ...

# %%
song_df.head()
# Out:
#                   song_id            song_name  duration_ms  \
# 0  6RLa40O5qY8xWKyyfw0zJ0              Sou Teu       203183
# 1  66TDFKCZpMRfLcgJpa15xq          Hier encore       143466
# 2  5txryUrKT15O1BCxIo88LR  Holy Forever (Live)       642837
# 3  5A6NI8jDFshJKTJmYQVgre               É Obra       230158
# 4  24qQClclS8CCjiCZKM8d9m     Njila ia Dikanga       341946
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/6RLa40O5qY8xWKy...          23
# 1  https://open.spotify.com/track/66TDFKCZpMRfLcg...          68
# 2  https://open.spotify.com/track/5txryUrKT15O1BC...          62
# 3  https://open.spotify.com/track/5A6NI8jDFshJKTJ...          41
# 4  https://open.spotify.com/track/24qQClclS8CCjiC...          44
#
#              song_added                   album               artist_id
# 0  2025-12-30T00:53:56Z  3h14xzfMIytpzYxO4BhruL  0LyfQWJT6nXafLPZqxe9Of
# ...

# %%
artist_df.head()
# Out:
#                 artist_id       artist_name  \
# 0  1uFzeVANATmuj4SchQpYnt         Telma Lee
# 1  2hgP9Ap2tc10R5jrQaEpMT  Charles Aznavour
# 2  26T4yOaOoFJvUvxR87Y9HO      Bethel Music
# 3  0cuW2lF0YWb9VUyHOnvnsO      Jenn Johnson
# 4  3qfrrrSO7utFdJkM2tvMRb       CeCe Winans
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/1uFzeVANATm...
# 1  https://api.spotify.com/v1/artists/2hgP9Ap2tc1...
# 2  https://api.spotify.com/v1/artists/26T4yOaOoFJ...
# 3  https://api.spotify.com/v1/artists/0cuW2lF0YWb...
# 4  https://api.spotify.com/v1/artists/3qfrrrSO7ut...

# %%
album_df.head()
# Out:
#                  album_id                     name release_date  total_tracks  \
# 0  3h14xzfMIytpzYxO4BhruL         I Love Kizomba 2   2019-08-09            22
# 1  3kZ8kQRYbgqgD5HVEsAzv1  Que c'est triste Venise   1964-01-01            12
# 2  7MwpCdsgZQTHDlDzqmVYuM      Holy Forever (Live)   2024-06-28             1
# 3  1QBkVr9PrI46C43cZclE4Z                  Emoções   2023-06-30            14
# 4  52CD0NEh9KfaGGIQRv478y            Independência   2021-04-30            10
#
#                                                  url
# 0  https://open.spotify.com/album/3h14xzfMIytpzYx...
# 1  https://open.spotify.com/album/3kZ8kQRYbgqgD5H...
# 2  https://open.spotify.com/album/7MwpCdsgZQTHDlD...
# 3  https://open.spotify.com/album/1QBkVr9PrI46C43...
# 4  https://open.spotify.com/album/52CD0NEh9KfaGGI...

# %%
album_df['release_date'] = pd.to_datetime(album_df['release_date'])

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      5 non-null      object
#  1   name          5 non-null      object
#  2   release_date  5 non-null      datetime64[ns]
#  3   total_tracks  5 non-null      int64
#  4   url           5 non-null      object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 332.0+ bytes

# %%
song_df['song_added'] = pd.to_datetime(song_df['song_added'])

# %%
song_df.head()
# Out:
#                   song_id            song_name  duration_ms  \
# 0  6RLa40O5qY8xWKyyfw0zJ0              Sou Teu       203183
# 1  66TDFKCZpMRfLcgJpa15xq          Hier encore       143466
# 2  5txryUrKT15O1BCxIo88LR  Holy Forever (Live)       642837
# 3  5A6NI8jDFshJKTJmYQVgre               É Obra       230158
# 4  24qQClclS8CCjiCZKM8d9m     Njila ia Dikanga       341946
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/6RLa40O5qY8xWKy...          23
# 1  https://open.spotify.com/track/66TDFKCZpMRfLcg...          68
# 2  https://open.spotify.com/track/5txryUrKT15O1BC...          62
# 3  https://open.spotify.com/track/5A6NI8jDFshJKTJ...          41
# 4  https://open.spotify.com/track/24qQClclS8CCjiC...          44
#
#                  song_added                   album               artist_id
# 0 2025-12-30 00:53:56+00:00  3h14xzfMIytpzYxO4BhruL  0LyfQWJT6nXafLPZqxe9Of
# ...

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      5 non-null      object
#  1   song_name    5 non-null      object
#  2   duration_ms  5 non-null      int64
#  3   url          5 non-null      object
#  4   popularity   5 non-null      int64
#  5   song_added   5 non-null      datetime64[ns, UTC]
#  6   album        5 non-null      object
#  7   artist_id    5 non-null      object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 452.0+ bytes
